# %% [markdown]
# # Usage of the solver

# %%
# General setup
from Solver import Solver
from Kripke import Model

# %% [markdown]
# explain some intro stuff here maybe

# %%
# Create solver here

# %%
# INPUT (will later be moved outside of this code so you can input it yourself, but for now this is an example of input you can give to run it)

worlds = ["w1", "w2", "w3", "w4"]

R = {
    "A": {
        "w1": {"w1"},
        "w2": {"w2"},
        "w3": {"w3"},
        "w4": {"w4"},
    },
    "B": {
        "w1": {"w1", "w2"},
        "w2": {"w2", "w3"},
        "w3": {"w1"},
        "w4": {"w1"},
    }
}

valuation = {
    "p": {"w1", "w2", "w3"}
}

formula = ("K", "A", ("K", "B", ("K", "A", ("K", "B", ("p",)))))

# To Do: make formula generator that matches the model

for i in range(100):
    Solver(formula, Model()).analyze()
# Out:
# 		No unique different answer found for each K operator removed.
# 		No unique different answer found for each K operator removed.
# 		No unique different answer found for each K operator removed.
# 		No unique different answer found for each K operator removed.
# 		No unique different answer found for each K operator removed.
# 		No unique different answer found for each K operator removed.
# 		No unique different answer found for each K operator removed.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 29
#      26 # To Do: make formula generator that matches the model
#      28 for i in range(100):
# ---> 29     Solver(formula, Model()).analyze()
#
# File c:\Users\elian\Documents\Uni\MSc\LAMAS\FP\LAMAS\src\Solver.py:41, in Solver.analyze(self)
#      38 answers = []
#      40 while True:
# ---> 41     ws = self.satisfying_worlds()
#      43     # print(f"\nToM level {self.level}")
#      44     if self.talks:
#
# File c:\Users\elian\Documents\Uni\MSc\LAMAS\FP\LAMAS\src\Solver.py:32, in Solver.satisfying_worlds(self)
#      31 def satisfying_worlds(self):
# ---> 32     return {w for w in self.w if self.eval_formula(self.f, w)}
#
# File c:\Users\elian\Documents\Uni\MSc\LAMAS\FP\LAMAS\src\Solver.py:32, in <setcomp>(.0)
#      31 def satisfying_worlds(self):
# ---> 32     return {w for w in self.w if self.eval_formula(self.f, w)}
#
# File c:\Users\elian\Documents\Uni\MSc\LAMAS\FP\LAMAS\src\Solver.py:28, in Solver.eval_formula(self, formula, world)
#      26 if formula[0] == "K":
#      27     agent, sub_formula = formula[1], formula[2]
# ---> 28     return all(self.eval_formula(sub_formula, connected_world)
#      29                for connected_world in self.r[agent][world])
#
# File c:\Users\elian\Documents\Uni\MSc\LAMAS\FP\LAMAS\src\Solver.py:28, in <genexpr>(.0)
#      26 if formula[0] == "K":
#      27     agent, sub_formula = formula[1], formula[2]
# ---> 28     return all(self.eval_formula(sub_formula, connected_world)
#      29                for connected_world in self.r[agent][world])
#
# File c:\Users\elian\Documents\Uni\MSc\LAMAS\FP\LAMAS\src\Solver.py:29, in Solver.eval_formula(self, formula, world)
#      26 if formula[0] == "K":
#      27     agent, sub_formula = formula[1], formula[2]
#      28     return all(self.eval_formula(sub_formula, connected_world)
# ---> 29                for connected_world in self.r[agent][world])
#
# KeyError: 'B'
